# %% [markdown]
# # Preliminary operations

# %%
#@title Drive mount

from google.colab import drive
drive.mount('/content/gdrive')

# %cd /content/gdrive/MyDrive/Assignment/OriginalDataset
# Out:
# Mounted at /content/gdrive
# /content/gdrive/MyDrive/Assignment/OriginalDataset

# %%
#@title Main libraries
import pandas as pd
import numpy as np

import os
import random

from sklearn.utils import  compute_class_weight

import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

from tensorflow.keras.preprocessing.image import ImageDataGenerator

from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix

import tensorflow as tf
tfk = tf.keras
tfkl = tf.keras.layers

# %%
#@title Reproducibility
# Setting a seed for reproducibility
seed = 90 
random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)
print("The seed is: " + str(seed))
# Out:
# The seed is: 90

# %% [markdown]
# # Access data

# %% [markdown]
# ### Data hyperparameters

# %%
data_hyperparameters = {
    'batch_size': 64,
    'resized_shape_height': 100,
    'resized_shape_width': 100,
    'color_mode': 'grayscale'
}

# %% [markdown]
# ### Defining augmentation

# %%
# This function is used to create a dictionary with the hyperparameters of the augmentation 
def get_augmentation_hyperparameters(selected_dictionary):
  
  if selected_dictionary==0:
    augmentation_hyperparameters={}
    augmentation_hyperparameters['name']= 'Basic_Augmentation'
    augmentation_hyperparameters['rotation_range']= 45
    augmentation_hyperparameters['width_shift_range']= 0
    augmentation_hyperparameters['height_shift_range']= 0
    augmentation_hyperparameters['brightness_range']= [0.8, 1.2]
    augmentation_hyperparameters['horizontal_flip']= True
    augmentation_hyperparameters['vertical_flip']= False
    augmentation_hyperparameters['zoom_range']= [0.7, 1.2]
    augmentation_hyperparameters['rescale_range']= 1/255.
    augmentation_hyperparameters['fill_mode']= 'reflect'
    augmentation_hyperparameters['cval']= 0
    
  elif selected_dictionary==1:
    augmentation_hyperparameters={}
    augmentation_hyperparameters['name']= 'Aggressive_Augmentation'
    augmentation_hyperparameters['rotation_range']= 90
    augmentation_hyperparameters['width_shift_range']= 0.2
    augmentation_hyperparameters['height_shift_range']= 0.2
    augmentation_hyperparameters['brightness_range']= [0.5, 1.5]
    augmentation_hyperparameters['horizontal_flip']= True
    augmentation_hyperparameters['vertical_flip']= False
    augmentation_hyperparameters['zoom_range']= [0.5, 1.5]
    augmentation_hyperparameters['rescale_range']= 1/255.
    augmentation_hyperparameters['fill_mode']= 'reflect'
    augmentation_hyperparameters['cval']= 0

  elif selected_dictionary==2:
    augmentation_hyperparameters={}
    augmentation_hyperparameters['name']= 'Kind_Augmentation'
    augmentation_hyperparameters['rotation_range']= 0
    augmentation_hyperparameters['width_shift_range']= 0.1
    augmentation_hyperparameters['height_shift_range']= 0.1
    augmentation_hyperparameters['brightness_range']=  [0.9, 1.1]
    augmentation_hyperparameters['horizontal_flip']= True
    augmentation_hyperparameters['vertical_flip']= False
    augmentation_hyperparameters['zoom_range']= [0.9, 1.1]
    augmentation_hyperparameters['rescale_range']= 1/255.
    augmentation_hyperparameters['fill_mode']= 'reflect'
    augmentation_hyperparameters['cval']= 0
  
  return augmentation_hyperparameters

# %%
dictionary = get_augmentation_hyperparameters(2)


aug_train_gen = ImageDataGenerator(
    rotation_range = dictionary['rotation_range'],
    height_shift_range = dictionary['height_shift_range'],
    width_shift_range = dictionary['width_shift_range'], 
    zoom_range = dictionary['zoom_range'],
    horizontal_flip = dictionary['horizontal_flip'],
    vertical_flip = dictionary['vertical_flip'], 
    fill_mode = dictionary['fill_mode'],
    cval = dictionary['cval'],
    rescale = dictionary['rescale_range'],
    brightness_range = dictionary['brightness_range'],
    #preprocessing_function= preprocess_input)
)

# %% [markdown]
# ### Data generators

# %%
dataset_dir = "/content/gdrive/MyDrive/Assignment/Clean_And_Preprocessed_Dataset/CLEAN_and_HMP/" 
training_dir = os.path.join(dataset_dir, 'TRAIN')
validation_dir = os.path.join(dataset_dir, 'VAL')
test_dir = os.path.join(dataset_dir, 'TEST')

# %%
aug_training_set = aug_train_gen.flow_from_directory(directory = training_dir,
                                                  target_size = (data_hyperparameters['resized_shape_height'], data_hyperparameters['resized_shape_width']),
                                                  color_mode = data_hyperparameters['color_mode'],
                                                  class_mode = 'categorical',
                                                  batch_size = data_hyperparameters['batch_size'],
                                                  shuffle = True,
                                                  seed = seed)

noaug_training_set = ImageDataGenerator(rescale = 1/255.).flow_from_directory(directory = training_dir,
                                                                              target_size = (data_hyperparameters['resized_shape_height'], data_hyperparameters['resized_shape_width']),
                                                                              color_mode = data_hyperparameters['color_mode'],
                                                                              class_mode = 'categorical',
                                                                              batch_size = data_hyperparameters['batch_size'],
                                                                              shuffle = True,
                                                                              seed = seed)

validation_set = ImageDataGenerator(rescale = 1/255.).flow_from_directory(directory = validation_dir,
                                                                target_size = (data_hyperparameters['resized_shape_height'], data_hyperparameters['resized_shape_width']),
                                                                color_mode = data_hyperparameters['color_mode'],
                                                                class_mode = 'categorical',
                                                                batch_size = data_hyperparameters['batch_size'],
                                                                shuffle = True,
                                                                seed = seed)
test_set = ImageDataGenerator(rescale = 1/255.).flow_from_directory(directory = test_dir,
                                                                target_size = (data_hyperparameters['resized_shape_height'], data_hyperparameters['resized_shape_width']),
                                                                color_mode = data_hyperparameters['color_mode'],
                                                                class_mode = 'categorical',
                                                                batch_size = data_hyperparameters['batch_size'],
                                                                shuffle = False,
                                                                seed = seed)
# Out:
# Found 11124 images belonging to 3 classes.
# Found 11124 images belonging to 3 classes.
# Found 1253 images belonging to 3 classes.
# Found 3093 images belonging to 3 classes.

# %%
# @title Target labels
labels = list(aug_training_set.class_indices.keys())
print("Labels: ", labels)
# Out:
# Labels:  ['normal', 'pneumonia', 'tubercolosis']

# %%
test_set.class_indices
# Out:
# {'normal': 0, 'pneumonia': 1, 'tubercolosis': 2}

# %% [markdown]
# # Model definition

# %% [markdown]
# ### Resnet with SE-blocks
# **Architecture**: Residual Network (ResNet)
#
# **Characteristics**: residual blocks exploiting skip connections, that allow the network to go deeper without suffering form the vanishing gradient problem. Actually, 2 types of residual blocks:
#
#  -  *convolutional blocks* = to reduce spatial extent and increase the Receptive Field
#
# -   *identity blocks* = shortcut that equalizes input and output block dimensions
#
# Both before the concatenation with the shortcut have a *Squeeze-and-Excite block* (abbreviated as SE-block) = to introduce a  channel attention mechanism

# %%
# @title Main blocks definition

def se_block(in_block, ch, ratio=16):
    x = tfkl.GlobalAveragePooling2D()(in_block)
    x = tfkl.Dense(ch//ratio, activation='relu')(x)
    x = tfkl.Dense(ch, activation='sigmoid')(x)
    x = tfkl.multiply([in_block, x])
    return x

def RN_Convolutional_block(block_input, num_filters, kernel_size=3, padding_mode='same', a_function='relu', dp_rate_1=0.3): 
   
  block_0 = tfkl.Conv2D( num_filters,
                            kernel_size= kernel_size,
                            strides= (2,2),
                            padding=padding_mode,
                            kernel_initializer= tfk.initializers.HeUniform(seed),
                            bias_initializer='zeros')(block_input)
  block_0 = tfkl.BatchNormalization()(block_0)
   
  block_1 = tfkl.Conv2D( num_filters,
                            kernel_size= kernel_size,
                            strides= (2,2),
                            padding=padding_mode,
                            kernel_initializer= tfk.initializers.HeUniform(seed),
                            bias_initializer='zeros')(block_input)
  block_1 = tfkl.BatchNormalization()(block_1)
  block_1 = tfkl.Activation(a_function)(block_1)
  block_1 = tfkl.Dropout(dp_rate_1)(block_1)

  block_2 = tfkl.Conv2D( num_filters,
                            kernel_size= kernel_size,
                            strides= (1,1),
                            padding=padding_mode,
                            kernel_initializer= tfk.initializers.HeUniform(seed),
                            bias_initializer='zeros')(block_1)
  block_2 = tfkl.BatchNormalization()(block_2)

  SE_block = se_block(block_2, ch=num_filters)

  concat = tfkl.Add()([block_0, SE_block])
  output = tfkl.Activation(a_function)(concat)

  return output

def RN_Identity_block(block_input, num_filters, kernel_size=3, padding_mode='same', a_function='relu', dp_rate_1=0.3): 

  block_1 = tfkl.Conv2D( num_filters,
                            kernel_size= kernel_size,
                            strides= (1,1),
                            padding=padding_mode,
                            kernel_initializer= tfk.initializers.HeUniform(seed),
                            bias_initializer='zeros')(block_input)
  block_1 = tfkl.BatchNormalization()(block_1)
  block_1 = tfkl.Activation(a_function)(block_1)
  block_1 = tfkl.Dropout(dp_rate_1)(block_1)

  block_2 = tfkl.Conv2D( num_filters,
                            kernel_size= kernel_size,
                            strides= (1,1),
                            padding=padding_mode,
                            kernel_initializer= tfk.initializers.HeUniform(seed),
                            bias_initializer='zeros')(block_1)
  block_2 = tfkl.BatchNormalization()(block_2)

  SE_block = se_block(block_2, ch=num_filters)

  concat = tfkl.Add()([block_input, SE_block])
  output = tfkl.Activation(a_function)(concat)

  return output

# %%
# @title Architecture

def ResNet(input_shape, n_output, N=8, kernel_size=3, padding_mode='same', a_function='relu', dp_rate =0.3, dp_rate_fc= 0.3, lr=1e-3): 
  input_layer = tfkl.Input(shape=input_shape, name='input_layer')

  RN_layers = tfkl.Conv2D( 64,
                            kernel_size= kernel_size,
                            strides= (1,1),
                            padding=padding_mode,
                            kernel_initializer= tfk.initializers.HeUniform(seed),
                            bias_initializer='zeros')(input_layer)
  RN_layers = tfkl.BatchNormalization()(RN_layers)
  RN_layers = tfkl.Activation(a_function)(RN_layers)
  RN_layers = tfkl.MaxPooling2D()(RN_layers)

  # The Resenet will have N blocks 
  # with n. filters starting at 64 and doubling every 2 blocks
  # first two blocks are Identity blocks
  # the following are Conv and Identity alternated
  num_filters = 64  

  RN_layers = RN_Identity_block(RN_layers, num_filters, kernel_size=3, padding_mode='same', a_function='relu', dp_rate_1= dp_rate)
  RN_layers = RN_Identity_block(RN_layers, num_filters, kernel_size=3, padding_mode='same', a_function='relu', dp_rate_1= dp_rate)

  for i in range(int((N-2)/2)):
    num_filters = num_filters*2

    RN_layers = RN_Convolutional_block(RN_layers, num_filters, kernel_size=3, padding_mode='same', a_function='relu', dp_rate_1= dp_rate)
    RN_layers = RN_Identity_block(RN_layers, num_filters, kernel_size=3, padding_mode='same', a_function='relu', dp_rate_1= dp_rate)


  # The top of the model will be a GAP + FC part
  RN_layers = tfkl.GlobalAveragePooling2D(name='GAP_layer')(RN_layers)
  FC_net = tfkl.Flatten(name='Flatten')(RN_layers)
  FC_net = tfkl.Dropout(dp_rate_fc, seed=seed)(FC_net)
  FC_net = tfkl.Dense(units= 512, name='Classifier', kernel_initializer=tfk.initializers.HeUniform(seed), activation='relu')(FC_net)
  FC_net = tfkl.Dropout(dp_rate_fc, seed=seed)(FC_net)
  FC_net = tfkl.Dense(units= n_output, name='Output', kernel_initializer=tfk.initializers.GlorotUniform(seed), activation='softmax')(FC_net)

  # input→output
  model = tfk.Model(inputs=input_layer, outputs=FC_net, name='ResNet')

  # Compile and return
  model.compile(loss=tfk.losses.CategoricalCrossentropy(), optimizer=tfk.optimizers.Adam(lr), metrics=['accuracy', 'Precision', 'Recall'])

  return model

# %%
# @title Building the model

n_channels = 1 if data_hyperparameters['color_mode']=='grayscale' else 3
input_shape = (data_hyperparameters['resized_shape_height'],data_hyperparameters['resized_shape_width'],n_channels) 
n_output = len(labels)

print(input_shape)
print(n_output)
# Out:
# (100, 100, 1)
# 3

# %%
Resnet_model = ResNet(input_shape, n_output, N=8, kernel_size=3, padding_mode='same', a_function='relu', dp_rate =0.3, dp_rate_fc= 0.3, lr=1e-3)

# %%
'''tfk.utils.plot_model(
    Resnet_model,
    to_file="models/ResNet_model_03012023.png",
    show_shapes=False,
    show_dtype=False,
    show_layer_names=True,
    rankdir="TB",
    expand_nested=False,
    dpi=96,
    #layer_range=None,
)'''
# Out:
# 'tfk.utils.plot_model(\n    Resnet_model,\n    to_file="models/ResNet_model_03012023.png",\n    show_shapes=False,\n    show_dtype=False,\n    show_layer_names=True,\n    rankdir="TB",\n    expand_nested=False,\n    dpi=96,\n    #layer_range=None,\n)'

# %%
Resnet_model.summary()
# Out:
# Model: "ResNet"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_layer (InputLayer)        [(None, 100, 100, 1) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 100, 100, 64) 640         input_layer[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 100, 100, 64) 256         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 100, 100, 64) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 50, 50, 64)   0           activation[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 50, 50, 64)   36928       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 50, 50, 64)   256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 50, 50, 64)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 50, 50, 64)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 50, 50, 64)   36928       dropout[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 50, 50, 64)   256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 64)           0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 4)            260         global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 64)           320         dense[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, 50, 50, 64)   0           batch_normalization_2[0][0]
#                                                                  dense_1[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 50, 50, 64)   0           max_pooling2d[0][0]
#                                                                  multiply[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 50, 50, 64)   0           add[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 50, 50, 64)   36928       activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 50, 50, 64)   256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 50, 50, 64)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 50, 50, 64)   0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 50, 50, 64)   36928       dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 50, 50, 64)   256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 64)           0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 4)            260         global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 64)           320         dense_2[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 50, 50, 64)   0           batch_normalization_4[0][0]
#                                                                  dense_3[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 50, 50, 64)   0           activation_2[0][0]
#                                                                  multiply_1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 50, 50, 64)   0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 25, 25, 128)  73856       activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 25, 25, 128)  512         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 25, 25, 128)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 25, 25, 128)  0           activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 25, 25, 128)  147584      dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 25, 25, 128)  512         conv2d_7[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 128)          0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 8)            1032        global_average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 25, 25, 128)  73856       activation_4[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 128)          1152        dense_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 25, 25, 128)  512         conv2d_5[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 25, 25, 128)  0           batch_normalization_7[0][0]
#                                                                  dense_5[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 25, 25, 128)  0           batch_normalization_5[0][0]
#                                                                  multiply_2[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 25, 25, 128)  0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 25, 25, 128)  147584      activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 25, 25, 128)  512         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 25, 25, 128)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 25, 25, 128)  0           activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 25, 25, 128)  147584      dropout_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 25, 25, 128)  512         conv2d_9[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_3 (Glo (None, 128)          0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 8)            1032        global_average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 128)          1152        dense_6[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 25, 25, 128)  0           batch_normalization_9[0][0]
#                                                                  dense_7[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 25, 25, 128)  0           activation_6[0][0]
#                                                                  multiply_3[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 25, 25, 128)  0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 13, 13, 256)  295168      activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 13, 13, 256)  1024        conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 13, 13, 256)  0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 13, 13, 256)  0           activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 13, 13, 256)  590080      dropout_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 13, 13, 256)  1024        conv2d_12[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_4 (Glo (None, 256)          0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 16)           4112        global_average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 13, 13, 256)  295168      activation_8[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 256)          4352        dense_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 13, 13, 256)  1024        conv2d_10[0][0]
# __________________________________________________________________________________________________
# multiply_4 (Multiply)           (None, 13, 13, 256)  0           batch_normalization_12[0][0]
#                                                                  dense_9[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 13, 13, 256)  0           batch_normalization_10[0][0]
#                                                                  multiply_4[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 13, 13, 256)  0           add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 13, 13, 256)  590080      activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 13, 13, 256)  1024        conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 13, 13, 256)  0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 13, 13, 256)  0           activation_11[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 13, 13, 256)  590080      dropout_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 13, 13, 256)  1024        conv2d_14[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_5 (Glo (None, 256)          0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 16)           4112        global_average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 256)          4352        dense_10[0][0]
# __________________________________________________________________________________________________
# multiply_5 (Multiply)           (None, 13, 13, 256)  0           batch_normalization_14[0][0]
#                                                                  dense_11[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 13, 13, 256)  0           activation_10[0][0]
#                                                                  multiply_5[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 13, 13, 256)  0           add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 7, 7, 512)    1180160     activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 7, 7, 512)    2048        conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 7, 7, 512)    0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 7, 7, 512)    0           activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 7, 7, 512)    2359808     dropout_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 7, 7, 512)    2048        conv2d_17[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_6 (Glo (None, 512)          0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 32)           16416       global_average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 7, 7, 512)    1180160     activation_12[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 512)          16896       dense_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 7, 7, 512)    2048        conv2d_15[0][0]
# __________________________________________________________________________________________________
# multiply_6 (Multiply)           (None, 7, 7, 512)    0           batch_normalization_17[0][0]
#                                                                  dense_13[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 7, 7, 512)    0           batch_normalization_15[0][0]
#                                                                  multiply_6[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 7, 7, 512)    0           add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 7, 7, 512)    2359808     activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 7, 7, 512)    2048        conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 7, 7, 512)    0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 7, 7, 512)    0           activation_15[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 7, 7, 512)    2359808     dropout_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 7, 7, 512)    2048        conv2d_19[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_7 (Glo (None, 512)          0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 32)           16416       global_average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 512)          16896       dense_14[0][0]
# __________________________________________________________________________________________________
# multiply_7 (Multiply)           (None, 7, 7, 512)    0           batch_normalization_19[0][0]
#                                                                  dense_15[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 7, 7, 512)    0           activation_14[0][0]
#                                                                  multiply_7[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 7, 7, 512)    0           add_7[0][0]
# __________________________________________________________________________________________________
# GAP_layer (GlobalAveragePooling (None, 512)          0           activation_16[0][0]
# __________________________________________________________________________________________________
# Flatten (Flatten)               (None, 512)          0           GAP_layer[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 512)          0           Flatten[0][0]
# __________________________________________________________________________________________________
# Classifier (Dense)              (None, 512)          262656      dropout_8[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 512)          0           Classifier[0][0]
# __________________________________________________________________________________________________
# Output (Dense)                  (None, 3)            1539        dropout_9[0][0]
# ==================================================================================================
# Total params: 12,911,611
# Trainable params: 12,902,011
# Non-trainable params: 9,600
# __________________________________________________________________________________________________

# %%
def evaluate_model_m(model, test_set, target):

  """ Function used to evaluate model's performances on the local test set, display of confusion matrix """
  """ Model from trained model variable """

  labels = list(test_set.class_indices.keys())
  
  predictions = model.predict(test_set)
  metrics= {
    "predictions" : predictions,
    "target": target,
    "cm": confusion_matrix(np.argmax(target, axis=-1), np.argmax(predictions, axis=-1), normalize='true', ),
    "accuracy" : accuracy_score(np.argmax(target, axis=-1), np.argmax(predictions, axis=-1)),
    "precision" : precision_score(np.argmax(target, axis=-1), np.argmax(predictions, axis=-1), average='macro'),
    "recall" : recall_score(np.argmax(target, axis=-1), np.argmax(predictions, axis=-1), average='macro'),
    "f1" : f1_score(np.argmax(target, axis=-1), np.argmax(predictions, axis=-1), average='macro')  }
  
  print("Accuracy: "+ str(metrics["accuracy"]))
  print("F1 score: "+ str(metrics["f1"]))
  cm = metrics["cm"]
  plt.figure(figsize=(15,15))
  sns.heatmap(cm.T, annot=True, fmt='.2f', xticklabels=list(labels), yticklabels=list(labels))
  plt.xlabel('True labels')
  plt.ylabel('Predicted labels')
  plt.show()

  return metrics

# %% [markdown]
# # Model training
# > Unbalanced dataset

# %%
train_gen = aug_training_set
valid_gen = validation_set
test_gen = test_set

train_target = train_gen.classes
val_target = valid_gen.classes
test_target = test_gen.classes

train_target_cat = tfk.utils.to_categorical(train_gen.classes)
val_target_cat = tfk.utils.to_categorical(valid_gen.classes)
test_target_cat = tfk.utils.to_categorical(test_gen.classes)

# %%
epochs = 200
bs = data_hyperparameters['batch_size']
class_weights = dict(zip(np.unique(train_target), compute_class_weight(class_weight = "balanced", classes = np.unique(train_target), y = train_target)))
monmtr = 'val_accuracy'

# %%
history = Resnet_model.fit(
    x = train_gen,
    epochs = epochs,
    #class_weight = class_weights,
    batch_size = bs, 
    validation_data = valid_gen,
    callbacks=[
        tfk.callbacks.EarlyStopping(monitor=monmtr, patience=20, restore_best_weights=True),
        tfk.callbacks.ReduceLROnPlateau(monitor=monmtr, patience=3, factor=0.5, min_lr=1e-8),
    ] 
).history
# Out:
# Epoch 1/200
# 174/174 [==============================] - 65s 346ms/step - loss: 0.6309 - accuracy: 0.7653 - precision: 0.7844 - recall: 0.7407 - val_loss: 2.0021 - val_accuracy: 0.5938 - val_precision: 0.5942 - val_recall: 0.5914
# Epoch 2/200
# 174/174 [==============================] - 16s 93ms/step - loss: 0.3874 - accuracy: 0.8485 - precision: 0.8601 - recall: 0.8341 - val_loss: 0.7182 - val_accuracy: 0.6664 - val_precision: 0.6688 - val_recall: 0.6656
# Epoch 3/200
# 174/174 [==============================] - 16s 91ms/step - loss: 0.3237 - accuracy: 0.8748 - precision: 0.8822 - recall: 0.8669 - val_loss: 0.6663 - val_accuracy: 0.7606 - val_precision: 0.7645 - val_recall: 0.7566
# Epoch 4/200
# 174/174 [==============================] - 16s 91ms/step - loss: 0.2825 - accuracy: 0.8913 - precision: 0.8971 - recall: 0.8858 - val_loss: 0.7522 - val_accuracy: 0.7997 - val_precision: 0.8006 - val_recall: 0.7981
# Epoch 5/200
# 174/174 [==============================] - 16s 91ms/step - loss: 0.2622 - accuracy: 0.9008 - precision: 0.9053 - recall: 0.8960 - val_loss: 0.7632 - val_accuracy: 0.7941 - val_precision: 0.7954 - val_recall: 0.7941
# Epoch 6/200
# 174/174 [==============================] - 16s 91ms/step - loss: 0.2375 - accuracy: 0.9127 - precision: 0.9163 - recall: 0.9094 - val_loss: 0.3471 - val_accuracy: 0.8579 - val_precision: 0.8655 - val_recall: 0.8524
# Epoch 7/200
# 174/174 [==============================] - 16s 90ms/step - loss: 0.2273 - accuracy: 0.9142 - precision: 0.9171 - recall: 0.9126 - val_loss: 0.4104 - val_accuracy: 0.8140 - val_precision: 0.8194 - val_recall: 0.8077
# Epoch 8/200
# 174/174 [==============================] - 16s 90ms/step - loss: 0.2150 - accuracy: 0.9190 - precision: 0.9217 - recall: 0.9156 - val_loss: 0.2949 - val_accuracy: 0.8867 - val_precision: 0.8891 - val_recall: 0.8827
# Epoch 9/200
# 174/174 [==============================] - 16s 90ms/step - loss: 0.2090 - accuracy: 0.9215 - precision: 0.9235 - recall: 0.9186 - val_loss: 0.2410 - val_accuracy: 0.8970 - val_precision: 0.8985 - val_recall: 0.8970
# Epoch 10/200
# 174/174 [==============================] - 16s 91ms/step - loss: 0.1958 - accuracy: 0.9252 - precision: 0.9272 - recall: 0.9235 - val_loss: 0.2496 - val_accuracy: 0.9130 - val_precision: 0.9130 - val_recall: 0.9130
# Epoch 11/200
# 174/174 [==============================] - 16s 90ms/step - loss: 0.1899 - accuracy: 0.9293 - precision: 0.9311 - recall: 0.9273 - val_loss: 0.1852 - val_accuracy: 0.9330 - val_precision: 0.9343 - val_recall: 0.9306
# Epoch 12/200
# 174/174 [==============================] - 16s 91ms/step - loss: 0.1742 - accuracy: 0.9354 - precision: 0.9368 - recall: 0.9334 - val_loss: 0.3749 - val_accuracy: 0.8571 - val_precision: 0.8594 - val_recall: 0.8540
# Epoch 13/200
# 174/174 [==============================] - 16s 91ms/step - loss: 0.1709 - accuracy: 0.9337 - precision: 0.9356 - recall: 0.9318 - val_loss: 0.2093 - val_accuracy: 0.9226 - val_precision: 0.9241 - val_recall: 0.9226
# Epoch 14/200
# 174/174 [==============================] - 16s 91ms/step - loss: 0.1793 - accuracy: 0.9333 - precision: 0.9344 - recall: 0.9314 - val_loss: 0.2098 - val_accuracy: 0.9162 - val_precision: 0.9176 - val_recall: 0.9154
# Epoch 15/200
# 174/174 [==============================] - 16s 91ms/step - loss: 0.1427 - accuracy: 0.9467 - precision: 0.9476 - recall: 0.9453 - val_loss: 0.2160 - val_accuracy: 0.9242 - val_precision: 0.9278 - val_recall: 0.9226
# Epoch 16/200
# 174/174 [==============================] - 16s 90ms/step - loss: 0.1359 - accuracy: 0.9480 - precision: 0.9487 - recall: 0.9472 - val_loss: 0.2252 - val_accuracy: 0.9250 - val_precision: 0.9263 - val_recall: 0.9226
# Epoch 17/200
# 174/174 [==============================] - 16s 90ms/step - loss: 0.1316 - accuracy: 0.9499 - precision: 0.9509 - recall: 0.9493 - val_loss: 0.3144 - val_accuracy: 0.9058 - val_precision: 0.9057 - val_recall: 0.9042
# Epoch 18/200
# 174/174 [==============================] - 16s 91ms/step - loss: 0.1189 - accuracy: 0.9542 - precision: 0.9545 - recall: 0.9534 - val_loss: 0.1544 - val_accuracy: 0.9417 - val_precision: 0.9416 - val_recall: 0.9401
# Epoch 19/200
# 174/174 [==============================] - 16s 91ms/step - loss: 0.1123 - accuracy: 0.9581 - precision: 0.9587 - recall: 0.9574 - val_loss: 0.2011 - val_accuracy: 0.9370 - val_precision: 0.9369 - val_recall: 0.9362
# Epoch 20/200
# 174/174 [==============================] - 16s 91ms/step - loss: 0.1129 - accuracy: 0.9568 - precision: 0.9574 - recall: 0.9566 - val_loss: 0.2029 - val_accuracy: 0.9298 - val_precision: 0.9304 - val_recall: 0.9282
# Epoch 21/200
# 174/174 [==============================] - 16s 91ms/step - loss: 0.1104 - accuracy: 0.9579 - precision: 0.9582 - recall: 0.9578 - val_loss: 0.1734 - val_accuracy: 0.9425 - val_precision: 0.9432 - val_recall: 0.9401
# Epoch 22/200
# 174/174 [==============================] - 16s 91ms/step - loss: 0.1054 - accuracy: 0.9603 - precision: 0.9603 - recall: 0.9599 - val_loss: 0.1693 - val_accuracy: 0.9417 - val_precision: 0.9439 - val_recall: 0.9401
# Epoch 23/200
# 174/174 [==============================] - 16s 91ms/step - loss: 0.1020 - accuracy: 0.9606 - precision: 0.9610 - recall: 0.9601 - val_loss: 0.1728 - val_accuracy: 0.9409 - val_precision: 0.9417 - val_recall: 0.9409
# Epoch 24/200
# 174/174 [==============================] - 16s 91ms/step - loss: 0.1051 - accuracy: 0.9609 - precision: 0.9614 - recall: 0.9604 - val_loss: 0.1779 - val_accuracy: 0.9393 - val_precision: 0.9408 - val_recall: 0.9393
# Epoch 25/200
# 174/174 [==============================] - 16s 91ms/step - loss: 0.0896 - accuracy: 0.9640 - precision: 0.9646 - recall: 0.9638 - val_loss: 0.2342 - val_accuracy: 0.9226 - val_precision: 0.9247 - val_recall: 0.9218
# Epoch 26/200
# 174/174 [==============================] - 16s 91ms/step - loss: 0.0846 - accuracy: 0.9701 - precision: 0.9702 - recall: 0.9697 - val_loss: 0.1876 - val_accuracy: 0.9393 - val_precision: 0.9393 - val_recall: 0.9385
# Epoch 27/200
# 174/174 [==============================] - 16s 91ms/step - loss: 0.0862 - accuracy: 0.9683 - precision: 0.9686 - recall: 0.9683 - val_loss: 0.1868 - val_accuracy: 0.9346 - val_precision: 0.9361 - val_recall: 0.9346
# Epoch 28/200
# 174/174 [==============================] - 16s 90ms/step - loss: 0.0837 - accuracy: 0.9668 - precision: 0.9671 - recall: 0.9666 - val_loss: 0.1902 - val_accuracy: 0.9338 - val_precision: 0.9337 - val_recall: 0.9322
# Epoch 29/200
# 174/174 [==============================] - 16s 91ms/step - loss: 0.0772 - accuracy: 0.9717 - precision: 0.9717 - recall: 0.9715 - val_loss: 0.1843 - val_accuracy: 0.9377 - val_precision: 0.9377 - val_recall: 0.9377
# Epoch 30/200
# 174/174 [==============================] - 16s 91ms/step - loss: 0.0817 - accuracy: 0.9691 - precision: 0.9693 - recall: 0.9689 - val_loss: 0.1778 - val_accuracy: 0.9433 - val_precision: 0.9441 - val_recall: 0.9433
# Epoch 31/200
# 174/174 [==============================] - 16s 91ms/step - loss: 0.0774 - accuracy: 0.9713 - precision: 0.9717 - recall: 0.9711 - val_loss: 0.1791 - val_accuracy: 0.9441 - val_precision: 0.9448 - val_recall: 0.9433
# Epoch 32/200
# 174/174 [==============================] - 16s 91ms/step - loss: 0.0756 - accuracy: 0.9723 - precision: 0.9726 - recall: 0.9721 - val_loss: 0.1822 - val_accuracy: 0.9370 - val_precision: 0.9370 - val_recall: 0.9370
# Epoch 33/200
# 174/174 [==============================] - 16s 91ms/step - loss: 0.0743 - accuracy: 0.9707 - precision: 0.9710 - recall: 0.9704 - val_loss: 0.1875 - val_accuracy: 0.9385 - val_precision: 0.9385 - val_recall: 0.9385
# Epoch 34/200
# 174/174 [==============================] - 16s 91ms/step - loss: 0.0775 - accuracy: 0.9697 - precision: 0.9697 - recall: 0.9695 - val_loss: 0.1972 - val_accuracy: 0.9330 - val_precision: 0.9329 - val_recall: 0.9322
# Epoch 35/200
# 174/174 [==============================] - 16s 91ms/step - loss: 0.0754 - accuracy: 0.9714 - precision: 0.9717 - recall: 0.9712 - val_loss: 0.1929 - val_accuracy: 0.9370 - val_precision: 0.9369 - val_recall: 0.9354
# Epoch 36/200
# 174/174 [==============================] - 16s 91ms/step - loss: 0.0697 - accuracy: 0.9723 - precision: 0.9727 - recall: 0.9722 - val_loss: 0.1992 - val_accuracy: 0.9306 - val_precision: 0.9321 - val_recall: 0.9306
# Epoch 37/200
# 174/174 [==============================] - 16s 91ms/step - loss: 0.0724 - accuracy: 0.9722 - precision: 0.9723 - recall: 0.9722 - val_loss: 0.1841 - val_accuracy: 0.9385 - val_precision: 0.9392 - val_recall: 0.9370
# Epoch 38/200
# 174/174 [==============================] - 16s 92ms/step - loss: 0.0702 - accuracy: 0.9739 - precision: 0.9739 - recall: 0.9737 - val_loss: 0.1952 - val_accuracy: 0.9338 - val_precision: 0.9345 - val_recall: 0.9330
# Epoch 39/200
# 174/174 [==============================] - 16s 91ms/step - loss: 0.0662 - accuracy: 0.9755 - precision: 0.9755 - recall: 0.9752 - val_loss: 0.1952 - val_accuracy: 0.9362 - val_precision: 0.9369 - val_recall: 0.9362
# Epoch 40/200
# 174/174 [==============================] - 16s 93ms/step - loss: 0.0702 - accuracy: 0.9737 - precision: 0.9737 - recall: 0.9734 - val_loss: 0.1961 - val_accuracy: 0.9377 - val_precision: 0.9385 - val_recall: 0.9377
# Epoch 41/200
# 174/174 [==============================] - 16s 91ms/step - loss: 0.0676 - accuracy: 0.9746 - precision: 0.9747 - recall: 0.9745 - val_loss: 0.1956 - val_accuracy: 0.9346 - val_precision: 0.9353 - val_recall: 0.9346
# Epoch 42/200
# 174/174 [==============================] - 16s 91ms/step - loss: 0.0692 - accuracy: 0.9728 - precision: 0.9728 - recall: 0.9727 - val_loss: 0.1959 - val_accuracy: 0.9338 - val_precision: 0.9338 - val_recall: 0.9338
# Epoch 43/200
# 174/174 [==============================] - 16s 90ms/step - loss: 0.0689 - accuracy: 0.9743 - precision: 0.9744 - recall: 0.9740 - val_loss: 0.1953 - val_accuracy: 0.9314 - val_precision: 0.9329 - val_recall: 0.9314
# Epoch 44/200
# 174/174 [==============================] - 16s 91ms/step - loss: 0.0649 - accuracy: 0.9753 - precision: 0.9754 - recall: 0.9751 - val_loss: 0.1939 - val_accuracy: 0.9370 - val_precision: 0.9370 - val_recall: 0.9370
# Epoch 45/200
# 174/174 [==============================] - 16s 91ms/step - loss: 0.0651 - accuracy: 0.9742 - precision: 0.9745 - recall: 0.9740 - val_loss: 0.1922 - val_accuracy: 0.9362 - val_precision: 0.9384 - val_recall: 0.9354
# Epoch 46/200
# 174/174 [==============================] - 16s 93ms/step - loss: 0.0646 - accuracy: 0.9751 - precision: 0.9752 - recall: 0.9749 - val_loss: 0.1920 - val_accuracy: 0.9393 - val_precision: 0.9393 - val_recall: 0.9385
# Epoch 47/200
# 174/174 [==============================] - 16s 94ms/step - loss: 0.0671 - accuracy: 0.9743 - precision: 0.9744 - recall: 0.9741 - val_loss: 0.1917 - val_accuracy: 0.9401 - val_precision: 0.9416 - val_recall: 0.9385
# Epoch 48/200
# 174/174 [==============================] - 16s 91ms/step - loss: 0.0644 - accuracy: 0.9748 - precision: 0.9750 - recall: 0.9748 - val_loss: 0.1921 - val_accuracy: 0.9393 - val_precision: 0.9408 - val_recall: 0.9385
# Epoch 49/200
# 174/174 [==============================] - 16s 91ms/step - loss: 0.0688 - accuracy: 0.9737 - precision: 0.9737 - recall: 0.9736 - val_loss: 0.1925 - val_accuracy: 0.9385 - val_precision: 0.9415 - val_recall: 0.9377
# Epoch 50/200
# 174/174 [==============================] - 16s 92ms/step - loss: 0.0636 - accuracy: 0.9757 - precision: 0.9758 - recall: 0.9755 - val_loss: 0.1929 - val_accuracy: 0.9377 - val_precision: 0.9400 - val_recall: 0.9377
# Epoch 51/200
# 174/174 [==============================] - 16s 92ms/step - loss: 0.0623 - accuracy: 0.9763 - precision: 0.9764 - recall: 0.9761 - val_loss: 0.1934 - val_accuracy: 0.9385 - val_precision: 0.9400 - val_recall: 0.9370

# %%
Resnet_model.save("C:/Users/Andrea Braccio/Desktop/HMP_ResNet_model_01022023") #save the model
# Out:
# C:\Anaconda\lib\site-packages\tensorflow\python\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# INFO:tensorflow:Assets written to: C:/Users/Andrea Braccio/Desktop/HMP_ResNet_model_01022023\assets

# %%
#m = Resnet_model
#m = tfk.models.load_model("models/ResNet_model_03012023")
# ret = evaluate_model_m(m, train_gen, train_target_cat)
# ret = evaluate_model_m(m, valid_gen, val_target_cat)
train200 = evaluate_model_m(Resnet_model, test_gen, test_target_cat)
# Out:
# Accuracy: 0.9553831231813773
# F1 score: 0.9416084832952768

# %%
arr_pred = np.asarray(train200['predictions'])

# %%
np.save('C:/Users/Andrea Braccio/Desktop/predictions_HMP_Resnet_010223.npy', arr_pred)

# %%
resnet = tfk.models.load_model("/content/gdrive/MyDrive/AI project/models/2.2. HMP_ResNet_model_01022023")

# %%
evaluate_model_m(resnet, test_gen, test_target_cat)

# %% [markdown]
# # Preliminary operations

# %%
#@title Drive mount
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#@title Main libraries
import pandas as pd
import numpy as np

import os
import random

from sklearn.utils import  compute_class_weight

import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

from tensorflow.keras.preprocessing.image import ImageDataGenerator

from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix

import tensorflow as tf
tfk = tf.keras
tfkl = tf.keras.layers

# %%
#@title Reproducibility
# Setting a seed for reproducibility
seed = 90 
random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)
print("The seed is: " + str(seed))
# Out:
# The seed is: 90

# %% [markdown]
# #Functions

# %%
def unfreeze_layers(tl_model, untill, supernet_name,lr):

  tl_model.get_layer(supernet_name).trainable = True
  for i, layer in enumerate(tl_model.get_layer(supernet_name).layers[:untill]):
    layer.trainable=False
  for i, layer in enumerate(tl_model.get_layer(supernet_name).layers):
    print(i, layer.name, layer.trainable)

  tl_model.compile(loss=tfk.losses.CategoricalCrossentropy(), optimizer=tfk.optimizers.Adam(lr), metrics=['accuracy', 'Precision', 'Recall'])

  return tl_model

# %%
def evaluate_model_m(model, test_set, target):

  """ Function used to evaluate model's performances on the local test set, display of confusion matrix """
  """ Model from trained model variable """

  labels = list(test_set.class_indices.keys())
  
  predictions = model.predict(test_set)
  metrics= {
    "predictions" : predictions,
    "target": target,
    "cm": confusion_matrix(np.argmax(target, axis=-1), np.argmax(predictions, axis=-1), normalize='true', ),
    "accuracy" : accuracy_score(np.argmax(target, axis=-1), np.argmax(predictions, axis=-1)),
    "precision" : precision_score(np.argmax(target, axis=-1), np.argmax(predictions, axis=-1), average='macro'),
    "recall" : recall_score(np.argmax(target, axis=-1), np.argmax(predictions, axis=-1), average='macro'),
    "f1" : f1_score(np.argmax(target, axis=-1), np.argmax(predictions, axis=-1), average='macro')  }
  
  print("Accuracy: "+ str(metrics["accuracy"]))
  print("F1 score: "+ str(metrics["f1"]))
  cm = metrics["cm"]
  plt.figure(figsize=(15,15))
  sns.heatmap(cm.T, annot=True, fmt='.2f', xticklabels=list(labels), yticklabels=list(labels))
  plt.xlabel('True labels')
  plt.ylabel('Predicted labels')
  plt.show()

  return metrics

# %% [markdown]
# # Access data

# %% [markdown]
# ### Data hyperparameters

# %%
data_hyperparameters = {
    'batch_size': 128,
    'resized_shape_height': 224, # as in chex net
    'resized_shape_width': 224,
    'color_mode': 'rgb' #'grayscale'
}

# %% [markdown]
# ### Defining augmentation

# %%
# This function is used to create a dictionary with the hyperparameters of the augmentation 
def get_augmentation_hyperparameters(selected_dictionary):
  
  if selected_dictionary==0:
    augmentation_hyperparameters={}
    augmentation_hyperparameters['name']= 'Basic_Augmentation'
    augmentation_hyperparameters['rotation_range']= 45
    augmentation_hyperparameters['width_shift_range']= 0
    augmentation_hyperparameters['height_shift_range']= 0
    augmentation_hyperparameters['brightness_range']= [0.8, 1.2]
    augmentation_hyperparameters['horizontal_flip']= True
    augmentation_hyperparameters['vertical_flip']= False
    augmentation_hyperparameters['zoom_range']= [0.7, 1.2]
    augmentation_hyperparameters['rescale_range']= 1/255.
    augmentation_hyperparameters['fill_mode']= 'reflect'
    augmentation_hyperparameters['cval']= 0
    
  elif selected_dictionary==1:
    augmentation_hyperparameters={}
    augmentation_hyperparameters['name']= 'Aggressive_Augmentation'
    augmentation_hyperparameters['rotation_range']= 90
    augmentation_hyperparameters['width_shift_range']= 0.2
    augmentation_hyperparameters['height_shift_range']= 0.2
    augmentation_hyperparameters['brightness_range']= [0.5, 1.5]
    augmentation_hyperparameters['horizontal_flip']= True
    augmentation_hyperparameters['vertical_flip']= False
    augmentation_hyperparameters['zoom_range']= [0.5, 1.5]
    augmentation_hyperparameters['rescale_range']= 1/255.
    augmentation_hyperparameters['fill_mode']= 'reflect'
    augmentation_hyperparameters['cval']= 0

  elif selected_dictionary==2:
    augmentation_hyperparameters={}
    augmentation_hyperparameters['name']= 'Kind_Augmentation'
    augmentation_hyperparameters['rotation_range']= 0
    augmentation_hyperparameters['width_shift_range']= 0.1
    augmentation_hyperparameters['height_shift_range']= 0.1
    augmentation_hyperparameters['brightness_range']=  [0.9, 1.1]
    augmentation_hyperparameters['horizontal_flip']= True
    augmentation_hyperparameters['vertical_flip']= False
    augmentation_hyperparameters['zoom_range']= [0.9, 1.1]
    #augmentation_hyperparameters['rescale_range']= 1.
    augmentation_hyperparameters['fill_mode']= 'reflect'
    augmentation_hyperparameters['cval']= 0
  
  return augmentation_hyperparameters

# %%
dictionary = get_augmentation_hyperparameters(2)


aug_train_gen = ImageDataGenerator(
    rotation_range = dictionary['rotation_range'],
    height_shift_range = dictionary['height_shift_range'],
    width_shift_range = dictionary['width_shift_range'], 
    zoom_range = dictionary['zoom_range'],
    horizontal_flip = dictionary['horizontal_flip'],
    vertical_flip = dictionary['vertical_flip'], 
    fill_mode = dictionary['fill_mode'],
    cval = dictionary['cval'],
    #rescale = dictionary['rescale_range'],
    brightness_range = dictionary['brightness_range'],
    #preprocessing_function= preprocess_input)
)

# %%
os.getcwd()
# Out:
# '/content'

# %% [markdown]
# ### Data generators

# %%
dataset_dir = "/content/gdrive/MyDrive/Assignment/Clean_And_Preprocessed_Dataset/CLEAN_and_FCDNP" #TODO
training_dir = os.path.join(dataset_dir, 'TRAIN')
validation_dir = os.path.join(dataset_dir, 'VAL')
test_dir = os.path.join(dataset_dir, 'TEST')

# %%
aug_training_set = aug_train_gen.flow_from_directory(directory = training_dir,
                                                  target_size = (data_hyperparameters['resized_shape_height'], data_hyperparameters['resized_shape_width']),
                                                  color_mode = data_hyperparameters['color_mode'],
                                                  class_mode = 'categorical',
                                                  batch_size = data_hyperparameters['batch_size'],
                                                  shuffle = True,
                                                  seed = seed)

noaug_training_set = ImageDataGenerator().flow_from_directory(directory = training_dir,
                                                                              target_size = (data_hyperparameters['resized_shape_height'], data_hyperparameters['resized_shape_width']),
                                                                              color_mode = data_hyperparameters['color_mode'],
                                                                              class_mode = 'categorical',
                                                                              batch_size = data_hyperparameters['batch_size'],
                                                                              shuffle = True,
                                                                              seed = seed)

validation_set = ImageDataGenerator().flow_from_directory(directory = validation_dir,
                                                                target_size = (data_hyperparameters['resized_shape_height'], data_hyperparameters['resized_shape_width']),
                                                                color_mode = data_hyperparameters['color_mode'],
                                                                class_mode = 'categorical',
                                                                batch_size = data_hyperparameters['batch_size'],
                                                                shuffle = True,
                                                                seed = seed)
test_set = ImageDataGenerator().flow_from_directory(directory = test_dir,
                                                                target_size = (data_hyperparameters['resized_shape_height'], data_hyperparameters['resized_shape_width']),
                                                                color_mode = data_hyperparameters['color_mode'],
                                                                class_mode = 'categorical',
                                                                batch_size = data_hyperparameters['batch_size'],
                                                                shuffle = False,
                                                                seed = seed)
# Out:
# Found 11124 images belonging to 3 classes.
# Found 11124 images belonging to 3 classes.
# Found 1253 images belonging to 3 classes.
# Found 3093 images belonging to 3 classes.

# %%
# @title Target labels
labels = list(aug_training_set.class_indices.keys())
print("Labels: ", labels)
# Out:
# Labels:  ['normal', 'pneumonia', 'tubercolosis']

# %%
# @title Defining input and output

n_channels = 1 if data_hyperparameters['color_mode']=='grayscale' else 3
input_shape = (data_hyperparameters['resized_shape_height'],data_hyperparameters['resized_shape_width'],n_channels) 
n_output = len(labels)

print(input_shape)
print(n_output)
# Out:
# (224, 224, 3)
# 3

# %% [markdown]
# # Model definition

# %%
# @title Building the model
base_model = tfk.applications.EfficientNetB0(
    include_top = False,
    weights = "imagenet",
    input_shape = input_shape
)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 [==============================] - 0s 0us/step

# %%
base_model.trainable = False

# %%
inputs = tfk.Input(shape = input_shape)

# %%
dp_rate1 = 0.3
dp_rate2 = 0.3
nc = 512
elastic_lambda= 1e-3

x = base_model(inputs, training=False)
x = tfk.layers.GlobalAveragePooling2D()(x)
x = tfkl.Dropout(dp_rate1, seed=seed)(x)
x = tfkl.Dense( 
      units=nc, 
      kernel_initializer = tfk.initializers.HeUniform(seed),
      kernel_regularizer=tf.keras.regularizers.L1L2(elastic_lambda,elastic_lambda))(x)
x=tfkl.LeakyReLU()(x)
x = tfkl.Dropout(dp_rate2, seed=seed)(x)

# %%
outputs = tfkl.Dense(
      n_output, 
      activation='softmax',
      kernel_initializer = tfk.initializers.GlorotUniform(seed))(x)

# %%
model = tfk.Model(inputs, outputs, name='model')

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  efficientnetb0 (Functional)  (None, 7, 7, 1280)       4049571
#
#  global_average_pooling2d (G  (None, 1280)             0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 1280)              0
#
#  dense (Dense)               (None, 512)               655872
#
#  leaky_re_lu (LeakyReLU)     (None, 512)               0
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 3)                 1539
#
# =================================================================
# Total params: 4,706,982
# Trainable params: 657,411
# Non-trainable params: 4,049,571
# _________________________________________________________________

# %%
unfreeze_layers(model, untill=207, supernet_name='efficientnetb0', lr = 1e-3)
# Out:
# 0 input_1 False
# 1 rescaling False
# 2 normalization False
# 3 tf.math.truediv False
# 4 stem_conv_pad False
# 5 stem_conv False
# 6 stem_bn False
# 7 stem_activation False
# 8 block1a_dwconv False
# 9 block1a_bn False
# 10 block1a_activation False
# 11 block1a_se_squeeze False
# 12 block1a_se_reshape False
# 13 block1a_se_reduce False
# 14 block1a_se_expand False
# 15 block1a_se_excite False
# 16 block1a_project_conv False
# 17 block1a_project_bn False
# 18 block2a_expand_conv False
# 19 block2a_expand_bn False
# 20 block2a_expand_activation False
# 21 block2a_dwconv_pad False
# 22 block2a_dwconv False
# 23 block2a_bn False
# 24 block2a_activation False
# 25 block2a_se_squeeze False
# 26 block2a_se_reshape False
# 27 block2a_se_reduce False
# 28 block2a_se_expand False
# 29 block2a_se_excite False
# 30 block2a_project_conv False
# 31 block2a_project_bn False
# 32 block2b_expand_conv False
# 33 block2b_expand_bn False
# 34 block2b_expand_activation False
# 35 block2b_dwconv False
# 36 block2b_bn False
# 37 block2b_activation False
# 38 block2b_se_squeeze False
# 39 block2b_se_reshape False
# 40 block2b_se_reduce False
# 41 block2b_se_expand False
# 42 block2b_se_excite False
# 43 block2b_project_conv False
# 44 block2b_project_bn False
# 45 block2b_drop False
# 46 block2b_add False
# 47 block3a_expand_conv False
# 48 block3a_expand_bn False
# 49 block3a_expand_activation False
# 50 block3a_dwconv_pad False
# 51 block3a_dwconv False
# 52 block3a_bn False
# 53 block3a_activation False
# 54 block3a_se_squeeze False
# 55 block3a_se_reshape False
# 56 block3a_se_reduce False
# 57 block3a_se_expand False
# 58 block3a_se_excite False
# 59 block3a_project_conv False
# 60 block3a_project_bn False
# 61 block3b_expand_conv False
# 62 block3b_expand_bn False
# 63 block3b_expand_activation False
# 64 block3b_dwconv False
# 65 block3b_bn False
# 66 block3b_activation False
# 67 block3b_se_squeeze False
# 68 block3b_se_reshape False
# 69 block3b_se_reduce False
# 70 block3b_se_expand False
# 71 block3b_se_excite False
# 72 block3b_project_conv False
# 73 block3b_project_bn False
# 74 block3b_drop False
# 75 block3b_add False
# 76 block4a_expand_conv False
# 77 block4a_expand_bn False
# 78 block4a_expand_activation False
# 79 block4a_dwconv_pad False
# 80 block4a_dwconv False
# 81 block4a_bn False
# 82 block4a_activation False
# 83 block4a_se_squeeze False
# 84 block4a_se_reshape False
# 85 block4a_se_reduce False
# 86 block4a_se_expand False
# 87 block4a_se_excite False
# 88 block4a_project_conv False
# 89 block4a_project_bn False
# 90 block4b_expand_conv False
# 91 block4b_expand_bn False
# 92 block4b_expand_activation False
# 93 block4b_dwconv False
# 94 block4b_bn False
# 95 block4b_activation False
# 96 block4b_se_squeeze False
# 97 block4b_se_reshape False
# 98 block4b_se_reduce False
# 99 block4b_se_expand False
# 100 block4b_se_excite False
# 101 block4b_project_conv False
# 102 block4b_project_bn False
# 103 block4b_drop False
# 104 block4b_add False
# 105 block4c_expand_conv False
# 106 block4c_expand_bn False
# 107 block4c_expand_activation False
# 108 block4c_dwconv False
# 109 block4c_bn False
# 110 block4c_activation False
# 111 block4c_se_squeeze False
# 112 block4c_se_reshape False
# 113 block4c_se_reduce False
# 114 block4c_se_expand False
# 115 block4c_se_excite False
# 116 block4c_project_conv False
# 117 block4c_project_bn False
# 118 block4c_drop False
# 119 block4c_add False
# 120 block5a_expand_conv False
# 121 block5a_expand_bn False
# 122 block5a_expand_activation False
# 123 block5a_dwconv False
# 124 block5a_bn False
# 125 block5a_activation False
# 126 block5a_se_squeeze False
# 127 block5a_se_reshape False
# 128 block5a_se_reduce False
# 129 block5a_se_expand False
# 130 block5a_se_excite False
# 131 block5a_project_conv False
# 132 block5a_project_bn False
# 133 block5b_expand_conv False
# 134 block5b_expand_bn False
# 135 block5b_expand_activation False
# 136 block5b_dwconv False
# 137 block5b_bn False
# 138 block5b_activation False
# 139 block5b_se_squeeze False
# 140 block5b_se_reshape False
# 141 block5b_se_reduce False
# 142 block5b_se_expand False
# 143 block5b_se_excite False
# 144 block5b_project_conv False
# 145 block5b_project_bn False
# 146 block5b_drop False
# 147 block5b_add False
# 148 block5c_expand_conv False
# 149 block5c_expand_bn False
# 150 block5c_expand_activation False
# 151 block5c_dwconv False
# 152 block5c_bn False
# 153 block5c_activation False
# 154 block5c_se_squeeze False
# 155 block5c_se_reshape False
# 156 block5c_se_reduce False
# 157 block5c_se_expand False
# 158 block5c_se_excite False
# 159 block5c_project_conv False
# 160 block5c_project_bn False
# 161 block5c_drop False
# 162 block5c_add False
# 163 block6a_expand_conv False
# 164 block6a_expand_bn False
# 165 block6a_expand_activation False
# 166 block6a_dwconv_pad False
# 167 block6a_dwconv False
# 168 block6a_bn False
# 169 block6a_activation False
# 170 block6a_se_squeeze False
# 171 block6a_se_reshape False
# 172 block6a_se_reduce False
# 173 block6a_se_expand False
# 174 block6a_se_excite False
# 175 block6a_project_conv False
# 176 block6a_project_bn False
# 177 block6b_expand_conv False
# 178 block6b_expand_bn False
# 179 block6b_expand_activation False
# 180 block6b_dwconv False
# 181 block6b_bn False
# 182 block6b_activation False
# 183 block6b_se_squeeze False
# 184 block6b_se_reshape False
# 185 block6b_se_reduce False
# 186 block6b_se_expand False
# 187 block6b_se_excite False
# 188 block6b_project_conv False
# 189 block6b_project_bn False
# 190 block6b_drop False
# 191 block6b_add False
# 192 block6c_expand_conv False
# 193 block6c_expand_bn False
# 194 block6c_expand_activation False
# 195 block6c_dwconv False
# 196 block6c_bn False
# 197 block6c_activation False
# 198 block6c_se_squeeze False
# 199 block6c_se_reshape False
# 200 block6c_se_reduce False
# 201 block6c_se_expand False
# 202 block6c_se_excite False
# 203 block6c_project_conv False
# 204 block6c_project_bn False
# 205 block6c_drop False
# 206 block6c_add False
# 207 block6d_expand_conv True
# 208 block6d_expand_bn True
# 209 block6d_expand_activation True
# 210 block6d_dwconv True
# 211 block6d_bn True
# 212 block6d_activation True
# 213 block6d_se_squeeze True
# 214 block6d_se_reshape True
# 215 block6d_se_reduce True
# 216 block6d_se_expand True
# 217 block6d_se_excite True
# 218 block6d_project_conv True
# 219 block6d_project_bn True
# 220 block6d_drop True
# 221 block6d_add True
# 222 block7a_expand_conv True
# 223 block7a_expand_bn True
# 224 block7a_expand_activation True
# 225 block7a_dwconv True
# 226 block7a_bn True
# 227 block7a_activation True
# 228 block7a_se_squeeze True
# 229 block7a_se_reshape True
# 230 block7a_se_reduce True
# 231 block7a_se_expand True
# 232 block7a_se_excite True
# 233 block7a_project_conv True
# 234 block7a_project_bn True
# 235 top_conv True
# 236 top_bn True
# 237 top_activation True

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  efficientnetb0 (Functional)  (None, 7, 7, 1280)       4049571
#
#  global_average_pooling2d (G  (None, 1280)             0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 1280)              0
#
#  dense (Dense)               (None, 512)               655872
#
#  leaky_re_lu (LeakyReLU)     (None, 512)               0
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 3)                 1539
#
# =================================================================
# Total params: 4,706,982
# Trainable params: 2,374,755
# Non-trainable params: 2,332,227
# _________________________________________________________________

# %% [markdown]
# # Model training

# %%
#@title Callbacks function 
Running_On_COLAB = 1
from datetime import datetime
def create_folders_and_callbacks(model_name):
    exps_dir = os.path.join('/content/gdrive/MyDrive/Assignment/MODELS',model_name)

    print("Model will be saved in: " + str(exps_dir))
    if not os.path.exists(exps_dir):
        os.makedirs(exps_dir)

    now = datetime.now().strftime('%b%d_%H-%M-%S')

    exp_dir = os.path.join(exps_dir, model_name + '_' + str(now))
    if not os.path.exists(exp_dir):
        os.makedirs(exp_dir)
      
    callbacks = []

    # Model checkpoint
    # ----------------
    ckpt_dir = os.path.join(exp_dir, 'ckpts')
    if not os.path.exists(ckpt_dir):
        os.makedirs(ckpt_dir)

    ckpt_callback = tf.keras.callbacks.ModelCheckpoint(filepath=os.path.join(ckpt_dir, 'cp.ckpt'), 
                                                     save_weights_only=True, # True to save only weights
                                                     save_best_only=False) # True to save only the best epoch 
    callbacks.append(ckpt_callback)


    # Early Stopping
    # --------------
    es_callback = tfk.callbacks.EarlyStopping(monitor=monmtr, patience=20, restore_best_weights=True)
    
    callbacks.append(es_callback)

    # Reduce LR by 1/2 when a plateau is reached
    reduce_LR_callback = tfk.callbacks.ReduceLROnPlateau(monitor=monmtr, patience=3, factor=0.5, min_lr=1e-8)
    callbacks.append(reduce_LR_callback)

    return callbacks

# %%
train_gen = aug_training_set
valid_gen = validation_set
test_gen = test_set

train_target = train_gen.classes
val_target = valid_gen.classes
test_target = test_gen.classes

train_target_cat = tfk.utils.to_categorical(train_gen.classes)
val_target_cat = tfk.utils.to_categorical(valid_gen.classes)
test_target_cat = tfk.utils.to_categorical(test_gen.classes)

# %% [markdown]
# ## Training 1

# %%
epochs = 20
bs = data_hyperparameters['batch_size']
class_weights = dict(zip(np.unique(train_target), compute_class_weight(class_weight = "balanced", classes = np.unique(train_target), y = train_target)))
monmtr = 'val_accuracy'

# %%
aug_callbacks = create_folders_and_callbacks(model_name= 'FCDNP_EffNet_Training1_pt2') # TODO X
# Out:
# Model will be saved in: /content/gdrive/MyDrive/Assignment/MODELS/FCDNP_EffNet_Training1_pt2

# %%
history = model.fit(
    x = train_gen,
    epochs = epochs,
    batch_size = bs, 
    validation_data = valid_gen,
    callbacks = aug_callbacks
).history
# Out:
# Epoch 1/40
# 87/87 [==============================] - 8486s 97s/step - loss: 9.6773 - accuracy: 0.8530 - precision: 0.8677 - recall: 0.8372 - val_loss: 1.3865 - val_accuracy: 0.9202 - val_precision: 0.9278 - val_recall: 0.9130 - lr: 0.0010
# Epoch 2/40
# 87/87 [==============================] - 161s 2s/step - loss: 0.7134 - accuracy: 0.9151 - precision: 0.9217 - recall: 0.9057 - val_loss: 0.4742 - val_accuracy: 0.9050 - val_precision: 0.9117 - val_recall: 0.8986 - lr: 0.0010
# Epoch 3/40
# 87/87 [==============================] - 160s 2s/step - loss: 0.3820 - accuracy: 0.9315 - precision: 0.9344 - recall: 0.9259 - val_loss: 0.3226 - val_accuracy: 0.9441 - val_precision: 0.9470 - val_recall: 0.9417 - lr: 0.0010
# Epoch 4/40
# 87/87 [==============================] - 161s 2s/step - loss: 0.3154 - accuracy: 0.9401 - precision: 0.9439 - recall: 0.9372 - val_loss: 0.3231 - val_accuracy: 0.9346 - val_precision: 0.9387 - val_recall: 0.9282 - lr: 0.0010
# Epoch 5/40
# 87/87 [==============================] - 160s 2s/step - loss: 0.2852 - accuracy: 0.9479 - precision: 0.9500 - recall: 0.9458 - val_loss: 0.2816 - val_accuracy: 0.9537 - val_precision: 0.9560 - val_recall: 0.9529 - lr: 0.0010
# Epoch 6/40
# 87/87 [==============================] - 161s 2s/step - loss: 0.2775 - accuracy: 0.9494 - precision: 0.9521 - recall: 0.9462 - val_loss: 0.2647 - val_accuracy: 0.9545 - val_precision: 0.9567 - val_recall: 0.9529 - lr: 0.0010
# Epoch 7/40
# 87/87 [==============================] - 162s 2s/step - loss: 0.2589 - accuracy: 0.9542 - precision: 0.9569 - recall: 0.9512 - val_loss: 0.2903 - val_accuracy: 0.9457 - val_precision: 0.9479 - val_recall: 0.9441 - lr: 0.0010
# Epoch 8/40
# 87/87 [==============================] - 163s 2s/step - loss: 0.2413 - accuracy: 0.9569 - precision: 0.9590 - recall: 0.9553 - val_loss: 0.2535 - val_accuracy: 0.9513 - val_precision: 0.9528 - val_recall: 0.9513 - lr: 0.0010
# Epoch 9/40
# 87/87 [==============================] - 163s 2s/step - loss: 0.2441 - accuracy: 0.9606 - precision: 0.9628 - recall: 0.9580 - val_loss: 0.2415 - val_accuracy: 0.9617 - val_precision: 0.9632 - val_recall: 0.9609 - lr: 0.0010
# Epoch 10/40
# 87/87 [==============================] - 163s 2s/step - loss: 0.2186 - accuracy: 0.9652 - precision: 0.9667 - recall: 0.9645 - val_loss: 0.2615 - val_accuracy: 0.9561 - val_precision: 0.9567 - val_recall: 0.9513 - lr: 0.0010
# Epoch 11/40
# 87/87 [==============================] - 164s 2s/step - loss: 0.2110 - accuracy: 0.9652 - precision: 0.9667 - recall: 0.9633 - val_loss: 0.3080 - val_accuracy: 0.9473 - val_precision: 0.9480 - val_recall: 0.9457 - lr: 0.0010
# Epoch 12/40
# 87/87 [==============================] - 162s 2s/step - loss: 0.1995 - accuracy: 0.9671 - precision: 0.9681 - recall: 0.9657 - val_loss: 0.2388 - val_accuracy: 0.9521 - val_precision: 0.9567 - val_recall: 0.9513 - lr: 0.0010
# Epoch 13/40
# 87/87 [==============================] - 163s 2s/step - loss: 0.1300 - accuracy: 0.9755 - precision: 0.9765 - recall: 0.9745 - val_loss: 0.2242 - val_accuracy: 0.9609 - val_precision: 0.9609 - val_recall: 0.9601 - lr: 5.0000e-04
# Epoch 14/40
# 87/87 [==============================] - 162s 2s/step - loss: 0.1260 - accuracy: 0.9769 - precision: 0.9776 - recall: 0.9765 - val_loss: 0.1859 - val_accuracy: 0.9593 - val_precision: 0.9593 - val_recall: 0.9585 - lr: 5.0000e-04
# Epoch 15/40
# 87/87 [==============================] - 162s 2s/step - loss: 0.1223 - accuracy: 0.9776 - precision: 0.9783 - recall: 0.9767 - val_loss: 0.1863 - val_accuracy: 0.9697 - val_precision: 0.9712 - val_recall: 0.9681 - lr: 5.0000e-04
# Epoch 16/40
# 87/87 [==============================] - 162s 2s/step - loss: 0.1144 - accuracy: 0.9818 - precision: 0.9823 - recall: 0.9804 - val_loss: 0.1827 - val_accuracy: 0.9729 - val_precision: 0.9751 - val_recall: 0.9705 - lr: 5.0000e-04
# Epoch 17/40
# 87/87 [==============================] - 161s 2s/step - loss: 0.1101 - accuracy: 0.9809 - precision: 0.9814 - recall: 0.9803 - val_loss: 0.1813 - val_accuracy: 0.9657 - val_precision: 0.9672 - val_recall: 0.9649 - lr: 5.0000e-04
# Epoch 18/40
# 87/87 [==============================] - 160s 2s/step - loss: 0.1068 - accuracy: 0.9817 - precision: 0.9822 - recall: 0.9809 - val_loss: 0.2104 - val_accuracy: 0.9641 - val_precision: 0.9663 - val_recall: 0.9625 - lr: 5.0000e-04
# Epoch 19/40
# 87/87 [==============================] - 160s 2s/step - loss: 0.1075 - accuracy: 0.9822 - precision: 0.9828 - recall: 0.9815 - val_loss: 0.1963 - val_accuracy: 0.9649 - val_precision: 0.9649 - val_recall: 0.9649 - lr: 5.0000e-04
# Epoch 20/40
# 87/87 [==============================] - 160s 2s/step - loss: 0.0702 - accuracy: 0.9880 - precision: 0.9886 - recall: 0.9876 - val_loss: 0.1917 - val_accuracy: 0.9649 - val_precision: 0.9649 - val_recall: 0.9649 - lr: 2.5000e-04
# Epoch 21/40
# 87/87 [==============================] - 161s 2s/step - loss: 0.0670 - accuracy: 0.9865 - precision: 0.9868 - recall: 0.9862 - val_loss: 0.1691 - val_accuracy: 0.9673 - val_precision: 0.9673 - val_recall: 0.9673 - lr: 2.5000e-04
# Epoch 22/40
# 87/87 [==============================] - 161s 2s/step - loss: 0.0621 - accuracy: 0.9880 - precision: 0.9882 - recall: 0.9877 - val_loss: 0.1740 - val_accuracy: 0.9665 - val_precision: 0.9665 - val_recall: 0.9665 - lr: 2.5000e-04
# Epoch 23/40
# 62/87 [====================>.........] - ETA: 44s - loss: 0.0507 - accuracy: 0.9890 - precision: 0.9893 - recall: 0.9890

# %%
#@title If need to restore from last checkpoint do it here:

# Restore the model from the latest checkpoint

latest = tf.train.latest_checkpoint("/content/gdrive/MyDrive/Assignment/MODELS/FCDNP_EffNet_Training1_pt2/FCDNP_EffNet_Training1_pt2_Jan31_21-33-17/ckpts")
print(latest)

answer = input('Do you wish to load last checkpoint ? (Y/N) ')

if answer=='Y':
  # Use the restored model and evaluate performances
  print('Loading checkpoint')
  model.load_weights(latest)
  #print("These were last time performances: ") 
  #[val_loss] = model.evaluate(valid_gen)
else:
    print('I will not reload since last checkpoint')
# Out:
# /content/gdrive/MyDrive/Assignment/MODELS/FCDNP_EffNet_Training1_pt2/FCDNP_EffNet_Training1_pt2_Jan31_21-33-17/ckpts/cp.ckpt
# Do you wish to load last checkpoint ? (Y/N) Y
# Loading checkpoint

# %%
model.save("/content/gdrive/MyDrive/Assignment/MODELS/FCDNP_EffNet_Training1/FCDNP_EffNet_Training1_Validation_97/model") #save the model
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 81). These functions will not be directly callable after loading.

# %%
history = model.fit( x = train_gen, epochs = epochs, batch_size = bs, validation_data = valid_gen, callbacks = aug_callbacks).history
# Out:
# Epoch 1/20
# 87/87 [==============================] - 6574s 75s/step - loss: 0.0615 - accuracy: 0.9895 - precision: 0.9900 - recall: 0.9889 - val_loss: 0.1753 - val_accuracy: 0.9681 - val_precision: 0.9681 - val_recall: 0.9681 - lr: 2.5000e-04
# Epoch 2/20
# 87/87 [==============================] - 160s 2s/step - loss: 0.0605 - accuracy: 0.9890 - precision: 0.9896 - recall: 0.9889 - val_loss: 0.1705 - val_accuracy: 0.9665 - val_precision: 0.9665 - val_recall: 0.9665 - lr: 2.5000e-04
# Epoch 3/20
# 87/87 [==============================] - 160s 2s/step - loss: 0.0617 - accuracy: 0.9891 - precision: 0.9895 - recall: 0.9889 - val_loss: 0.1843 - val_accuracy: 0.9649 - val_precision: 0.9649 - val_recall: 0.9649 - lr: 2.5000e-04
# Epoch 4/20
# 87/87 [==============================] - 160s 2s/step - loss: 0.0643 - accuracy: 0.9882 - precision: 0.9887 - recall: 0.9879 - val_loss: 0.1883 - val_accuracy: 0.9737 - val_precision: 0.9737 - val_recall: 0.9737 - lr: 2.5000e-04
# Epoch 5/20
# 87/87 [==============================] - 160s 2s/step - loss: 0.0649 - accuracy: 0.9885 - precision: 0.9889 - recall: 0.9883 - val_loss: 0.1788 - val_accuracy: 0.9601 - val_precision: 0.9609 - val_recall: 0.9601 - lr: 2.5000e-04
# Epoch 6/20
# 87/87 [==============================] - 160s 2s/step - loss: 0.0621 - accuracy: 0.9891 - precision: 0.9894 - recall: 0.9888 - val_loss: 0.1974 - val_accuracy: 0.9625 - val_precision: 0.9625 - val_recall: 0.9625 - lr: 2.5000e-04
# Epoch 7/20
# 87/87 [==============================] - 160s 2s/step - loss: 0.0596 - accuracy: 0.9905 - precision: 0.9909 - recall: 0.9902 - val_loss: 0.1789 - val_accuracy: 0.9649 - val_precision: 0.9649 - val_recall: 0.9649 - lr: 2.5000e-04
# Epoch 8/20
# 87/87 [==============================] - 159s 2s/step - loss: 0.0407 - accuracy: 0.9928 - precision: 0.9932 - recall: 0.9927 - val_loss: 0.1779 - val_accuracy: 0.9681 - val_precision: 0.9688 - val_recall: 0.9681 - lr: 1.2500e-04
# Epoch 9/20
# 87/87 [==============================] - 160s 2s/step - loss: 0.0368 - accuracy: 0.9936 - precision: 0.9937 - recall: 0.9933 - val_loss: 0.1719 - val_accuracy: 0.9737 - val_precision: 0.9737 - val_recall: 0.9737 - lr: 1.2500e-04
# Epoch 10/20
# 87/87 [==============================] - 159s 2s/step - loss: 0.0378 - accuracy: 0.9926 - precision: 0.9930 - recall: 0.9924 - val_loss: 0.1630 - val_accuracy: 0.9681 - val_precision: 0.9696 - val_recall: 0.9681 - lr: 1.2500e-04
# Epoch 11/20
# 87/87 [==============================] - 160s 2s/step - loss: 0.0322 - accuracy: 0.9933 - precision: 0.9933 - recall: 0.9930 - val_loss: 0.1509 - val_accuracy: 0.9713 - val_precision: 0.9713 - val_recall: 0.9713 - lr: 6.2500e-05
# Epoch 12/20
# 87/87 [==============================] - 160s 2s/step - loss: 0.0277 - accuracy: 0.9941 - precision: 0.9942 - recall: 0.9938 - val_loss: 0.1789 - val_accuracy: 0.9681 - val_precision: 0.9681 - val_recall: 0.9681 - lr: 6.2500e-05
# Epoch 13/20
# 87/87 [==============================] - 160s 2s/step - loss: 0.0253 - accuracy: 0.9947 - precision: 0.9950 - recall: 0.9944 - val_loss: 0.1891 - val_accuracy: 0.9657 - val_precision: 0.9657 - val_recall: 0.9657 - lr: 6.2500e-05
# Epoch 14/20
# 87/87 [==============================] - 160s 2s/step - loss: 0.0258 - accuracy: 0.9939 - precision: 0.9940 - recall: 0.9937 - val_loss: 0.1812 - val_accuracy: 0.9641 - val_precision: 0.9641 - val_recall: 0.9641 - lr: 3.1250e-05
# Epoch 15/20
# 87/87 [==============================] - 160s 2s/step - loss: 0.0236 - accuracy: 0.9949 - precision: 0.9951 - recall: 0.9949 - val_loss: 0.1727 - val_accuracy: 0.9657 - val_precision: 0.9657 - val_recall: 0.9657 - lr: 3.1250e-05
# Epoch 16/20
# 87/87 [==============================] - 160s 2s/step - loss: 0.0236 - accuracy: 0.9955 - precision: 0.9957 - recall: 0.9954 - val_loss: 0.1794 - val_accuracy: 0.9665 - val_precision: 0.9665 - val_recall: 0.9665 - lr: 3.1250e-05
# Epoch 17/20
# 87/87 [==============================] - 160s 2s/step - loss: 0.0189 - accuracy: 0.9963 - precision: 0.9965 - recall: 0.9962 - val_loss: 0.1775 - val_accuracy: 0.9665 - val_precision: 0.9665 - val_recall: 0.9665 - lr: 1.5625e-05
# Epoch 18/20
# 87/87 [==============================] - 160s 2s/step - loss: 0.0203 - accuracy: 0.9950 - precision: 0.9950 - recall: 0.9948 - val_loss: 0.1759 - val_accuracy: 0.9673 - val_precision: 0.9673 - val_recall: 0.9673 - lr: 1.5625e-05
# Epoch 19/20
# 87/87 [==============================] - 159s 2s/step - loss: 0.0191 - accuracy: 0.9950 - precision: 0.9951 - recall: 0.9950 - val_loss: 0.1768 - val_accuracy: 0.9673 - val_precision: 0.9673 - val_recall: 0.9673 - lr: 1.5625e-05
# Epoch 20/20
# 87/87 [==============================] - 160s 2s/step - loss: 0.0177 - accuracy: 0.9958 - precision: 0.9958 - recall: 0.9956 - val_loss: 0.1671 - val_accuracy: 0.9697 - val_precision: 0.9697 - val_recall: 0.9697 - lr: 7.8125e-06

# %% [markdown]
# ## Model evaluation 1
#
# Qui valuto il modello allenato precedentemente con X epoche, con settato a trainable fino al layer 207.
# Il modello è stato salvato in "/content/gdrive/MyDrive/MODELS/FCDNP_EffNet_model_31_01"

# %%
#model = tfk.models.load_model("/content/gdrive/MyDrive/MODELS/FCDNP_EffNet_model_31_01")
# ret = evaluate_model_m(m, train_gen, train_target_cat)
# ret = evaluate_model_m(m, valid_gen, val_target_cat)
train1 = evaluate_model_m(model, test_gen, test_target_cat)
# Out:
# 25/25 [==============================] - 309s 12s/step
# Accuracy: 0.9595861623019722
# F1 score: 0.9450221382218501

# %%
import pickle 

with open('/content/gdrive/MyDrive/Assignment/MODELS/FCDNP_EffNet_Training1_pt2/perfomances1_FCDNP_EffNet_model_31_01.pkl', 'wb') as f: #TODO X
    pickle.dump(train1, f)

# %%
#model = tfk.models.load_model("/content/gdrive/MyDrive/MODELS/FCDNP_EffNet_model_31_01")i
#model.summary()
model.save('/content/gdrive/MyDrive/Assignment/MODELS/FCDNP_EffNet_Training1_pt2/model')
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 81). These functions will not be directly callable after loading.

# %% [markdown]
# ##Training 2

# %%
model = tfk.models.load_model('/content/gdrive/MyDrive/Assignment/MODELS/FCDNP_EffNet_Training1_pt2/model')

# %%
epochs = 10
bs = data_hyperparameters['batch_size']
class_weights = dict(zip(np.unique(train_target), compute_class_weight(class_weight = "balanced", classes = np.unique(train_target), y = train_target)))
monmtr = 'val_accuracy'

# %%
aug_callbacks = create_folders_and_callbacks(model_name='FCDNP_EffNet_Training2')
# Out:
# Model will be saved in: /content/gdrive/MyDrive/Assignment/MODELS/FCDNP_EffNet_Training2

# %%
unfreeze_layers(model, untill=163, supernet_name='efficientnetb0', lr = 1e-3)
model.summary()
# Out:
# 0 input_1 False
# 1 rescaling False
# 2 normalization False
# 3 tf.math.truediv False
# 4 stem_conv_pad False
# 5 stem_conv False
# 6 stem_bn False
# 7 stem_activation False
# 8 block1a_dwconv False
# 9 block1a_bn False
# 10 block1a_activation False
# 11 block1a_se_squeeze False
# 12 block1a_se_reshape False
# 13 block1a_se_reduce False
# 14 block1a_se_expand False
# 15 block1a_se_excite False
# 16 block1a_project_conv False
# 17 block1a_project_bn False
# 18 block2a_expand_conv False
# 19 block2a_expand_bn False
# 20 block2a_expand_activation False
# 21 block2a_dwconv_pad False
# 22 block2a_dwconv False
# 23 block2a_bn False
# 24 block2a_activation False
# 25 block2a_se_squeeze False
# 26 block2a_se_reshape False
# 27 block2a_se_reduce False
# 28 block2a_se_expand False
# 29 block2a_se_excite False
# 30 block2a_project_conv False
# 31 block2a_project_bn False
# 32 block2b_expand_conv False
# 33 block2b_expand_bn False
# 34 block2b_expand_activation False
# 35 block2b_dwconv False
# 36 block2b_bn False
# 37 block2b_activation False
# 38 block2b_se_squeeze False
# 39 block2b_se_reshape False
# 40 block2b_se_reduce False
# 41 block2b_se_expand False
# 42 block2b_se_excite False
# 43 block2b_project_conv False
# 44 block2b_project_bn False
# 45 block2b_drop False
# 46 block2b_add False
# 47 block3a_expand_conv False
# 48 block3a_expand_bn False
# 49 block3a_expand_activation False
# 50 block3a_dwconv_pad False
# 51 block3a_dwconv False
# 52 block3a_bn False
# 53 block3a_activation False
# 54 block3a_se_squeeze False
# 55 block3a_se_reshape False
# 56 block3a_se_reduce False
# 57 block3a_se_expand False
# 58 block3a_se_excite False
# 59 block3a_project_conv False
# 60 block3a_project_bn False
# 61 block3b_expand_conv False
# 62 block3b_expand_bn False
# 63 block3b_expand_activation False
# 64 block3b_dwconv False
# 65 block3b_bn False
# 66 block3b_activation False
# 67 block3b_se_squeeze False
# 68 block3b_se_reshape False
# 69 block3b_se_reduce False
# 70 block3b_se_expand False
# 71 block3b_se_excite False
# 72 block3b_project_conv False
# 73 block3b_project_bn False
# 74 block3b_drop False
# 75 block3b_add False
# 76 block4a_expand_conv False
# 77 block4a_expand_bn False
# 78 block4a_expand_activation False
# 79 block4a_dwconv_pad False
# 80 block4a_dwconv False
# 81 block4a_bn False
# 82 block4a_activation False
# 83 block4a_se_squeeze False
# 84 block4a_se_reshape False
# 85 block4a_se_reduce False
# 86 block4a_se_expand False
# 87 block4a_se_excite False
# 88 block4a_project_conv False
# 89 block4a_project_bn False
# 90 block4b_expand_conv False
# 91 block4b_expand_bn False
# 92 block4b_expand_activation False
# 93 block4b_dwconv False
# 94 block4b_bn False
# 95 block4b_activation False
# 96 block4b_se_squeeze False
# 97 block4b_se_reshape False
# 98 block4b_se_reduce False
# 99 block4b_se_expand False
# 100 block4b_se_excite False
# 101 block4b_project_conv False
# 102 block4b_project_bn False
# 103 block4b_drop False
# 104 block4b_add False
# 105 block4c_expand_conv False
# 106 block4c_expand_bn False
# 107 block4c_expand_activation False
# 108 block4c_dwconv False
# 109 block4c_bn False
# 110 block4c_activation False
# 111 block4c_se_squeeze False
# 112 block4c_se_reshape False
# 113 block4c_se_reduce False
# 114 block4c_se_expand False
# 115 block4c_se_excite False
# 116 block4c_project_conv False
# 117 block4c_project_bn False
# 118 block4c_drop False
# 119 block4c_add False
# 120 block5a_expand_conv False
# 121 block5a_expand_bn False
# 122 block5a_expand_activation False
# 123 block5a_dwconv False
# 124 block5a_bn False
# 125 block5a_activation False
# 126 block5a_se_squeeze False
# 127 block5a_se_reshape False
# 128 block5a_se_reduce False
# 129 block5a_se_expand False
# 130 block5a_se_excite False
# 131 block5a_project_conv False
# 132 block5a_project_bn False
# 133 block5b_expand_conv False
# 134 block5b_expand_bn False
# 135 block5b_expand_activation False
# 136 block5b_dwconv False
# 137 block5b_bn False
# 138 block5b_activation False
# 139 block5b_se_squeeze False
# 140 block5b_se_reshape False
# 141 block5b_se_reduce False
# 142 block5b_se_expand False
# 143 block5b_se_excite False
# 144 block5b_project_conv False
# 145 block5b_project_bn False
# 146 block5b_drop False
# 147 block5b_add False
# 148 block5c_expand_conv False
# 149 block5c_expand_bn False
# 150 block5c_expand_activation False
# 151 block5c_dwconv False
# 152 block5c_bn False
# 153 block5c_activation False
# 154 block5c_se_squeeze False
# 155 block5c_se_reshape False
# 156 block5c_se_reduce False
# 157 block5c_se_expand False
# 158 block5c_se_excite False
# 159 block5c_project_conv False
# 160 block5c_project_bn False
# 161 block5c_drop False
# 162 block5c_add False
# 163 block6a_expand_conv True
# 164 block6a_expand_bn True
# 165 block6a_expand_activation True
# 166 block6a_dwconv_pad True
# 167 block6a_dwconv True
# 168 block6a_bn True
# 169 block6a_activation True
# 170 block6a_se_squeeze True
# 171 block6a_se_reshape True
# 172 block6a_se_reduce True
# 173 block6a_se_expand True
# 174 block6a_se_excite True
# 175 block6a_project_conv True
# 176 block6a_project_bn True
# 177 block6b_expand_conv True
# 178 block6b_expand_bn True
# 179 block6b_expand_activation True
# 180 block6b_dwconv True
# 181 block6b_bn True
# 182 block6b_activation True
# 183 block6b_se_squeeze True
# 184 block6b_se_reshape True
# 185 block6b_se_reduce True
# 186 block6b_se_expand True
# 187 block6b_se_excite True
# 188 block6b_project_conv True
# 189 block6b_project_bn True
# 190 block6b_drop True
# 191 block6b_add True
# 192 block6c_expand_conv True
# 193 block6c_expand_bn True
# 194 block6c_expand_activation True
# 195 block6c_dwconv True
# 196 block6c_bn True
# 197 block6c_activation True
# 198 block6c_se_squeeze True
# 199 block6c_se_reshape True
# 200 block6c_se_reduce True
# 201 block6c_se_expand True
# 202 block6c_se_excite True
# 203 block6c_project_conv True
# 204 block6c_project_bn True
# 205 block6c_drop True
# 206 block6c_add True
# 207 block6d_expand_conv True
# 208 block6d_expand_bn True
# 209 block6d_expand_activation True
# 210 block6d_dwconv True
# 211 block6d_bn True
# 212 block6d_activation True
# 213 block6d_se_squeeze True
# 214 block6d_se_reshape True
# 215 block6d_se_reduce True
# 216 block6d_se_expand True
# 217 block6d_se_excite True
# 218 block6d_project_conv True
# 219 block6d_project_bn True
# 220 block6d_drop True
# 221 block6d_add True
# 222 block7a_expand_conv True
# 223 block7a_expand_bn True
# 224 block7a_expand_activation True
# 225 block7a_dwconv True
# 226 block7a_bn True
# 227 block7a_activation True
# 228 block7a_se_squeeze True
# 229 block7a_se_reshape True
# 230 block7a_se_reduce True
# 231 block7a_se_expand True
# 232 block7a_se_excite True
# 233 block7a_project_conv True
# 234 block7a_project_bn True
# 235 top_conv True
# 236 top_bn True
# 237 top_activation True
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  efficientnetb0 (Functional)  (None, 7, 7, 1280)       4049571
#
#  global_average_pooling2d (G  (None, 1280)             0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 1280)              0
#
#  dense (Dense)               (None, 512)               655872
#
#  leaky_re_lu (LeakyReLU)     (None, 512)               0
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 3)                 1539
#
# =================================================================
# Total params: 4,706,982
# Trainable params: 3,813,151
# Non-trainable params: 893,831
# _________________________________________________________________

# %%
#@title If need to restore from last checkpoint do it here:

# Restore the model from the latest checkpoint

latest = tf.train.latest_checkpoint("/content/gdrive/MyDrive/Assignment/MODELS/FCDNP_EffNet_Training2/FCDNP_EffNet_Training2_Feb01_14-30-13/ckpts")
print(latest)

answer = input('Do you wish to load last checkpoint ? (Y/N) ')

if answer=='Y':
  # Use the restored model and evaluate performances
  print('Loading checkpoint')
  model.load_weights(latest)
  #print("These were last time performances: ") 
  #[val_loss] = model.evaluate(valid_gen)
else:
    print('I will not reload since last checkpoint')
# Out:
# /content/gdrive/MyDrive/Assignment/MODELS/FCDNP_EffNet_Training2/FCDNP_EffNet_Training2_Feb01_14-30-13/ckpts/cp.ckpt
# Do you wish to load last checkpoint ? (Y/N) Y
# Loading checkpoint

# %%
history = model.fit(
    x = train_gen,
    epochs = epochs,
    #class_weight = class_weights,
    batch_size = bs, 
    validation_data = valid_gen,
    callbacks = aug_callbacks
).history
# Out:
# Epoch 1/10
# 87/87 [==============================] - 3000s 34s/step - loss: 0.0152 - accuracy: 0.9973 - precision: 0.9974 - recall: 0.9973 - val_loss: 0.2249 - val_accuracy: 0.9625 - val_precision: 0.9625 - val_recall: 0.9625 - lr: 1.0000e-05
# Epoch 2/10
# 87/87 [==============================] - 1148s 13s/step - loss: 0.0179 - accuracy: 0.9960 - precision: 0.9962 - recall: 0.9959 - val_loss: 0.1973 - val_accuracy: 0.9673 - val_precision: 0.9681 - val_recall: 0.9673 - lr: 1.0000e-05
# Epoch 3/10
# 87/87 [==============================] - 1136s 13s/step - loss: 0.0195 - accuracy: 0.9961 - precision: 0.9961 - recall: 0.9961 - val_loss: 0.2055 - val_accuracy: 0.9657 - val_precision: 0.9657 - val_recall: 0.9657 - lr: 1.0000e-05
# Epoch 4/10
# 87/87 [==============================] - 1141s 13s/step - loss: 0.0154 - accuracy: 0.9975 - precision: 0.9977 - recall: 0.9974 - val_loss: 0.1976 - val_accuracy: 0.9673 - val_precision: 0.9673 - val_recall: 0.9665 - lr: 1.0000e-05
# Epoch 5/10
# 87/87 [==============================] - 1159s 13s/step - loss: 0.0158 - accuracy: 0.9969 - precision: 0.9971 - recall: 0.9969 - val_loss: 0.1882 - val_accuracy: 0.9673 - val_precision: 0.9681 - val_recall: 0.9673 - lr: 1.0000e-05
# Epoch 6/10
# 87/87 [==============================] - 1143s 13s/step - loss: 0.0166 - accuracy: 0.9963 - precision: 0.9963 - recall: 0.9963 - val_loss: 0.1861 - val_accuracy: 0.9681 - val_precision: 0.9681 - val_recall: 0.9681 - lr: 5.0000e-06
# Epoch 7/10
# 87/87 [==============================] - 1146s 13s/step - loss: 0.0166 - accuracy: 0.9966 - precision: 0.9967 - recall: 0.9964 - val_loss: 0.1891 - val_accuracy: 0.9665 - val_precision: 0.9665 - val_recall: 0.9665 - lr: 5.0000e-06
# Epoch 8/10
# 87/87 [==============================] - 1137s 13s/step - loss: 0.0162 - accuracy: 0.9960 - precision: 0.9961 - recall: 0.9960 - val_loss: 0.1936 - val_accuracy: 0.9665 - val_precision: 0.9665 - val_recall: 0.9665 - lr: 5.0000e-06
# Epoch 9/10
# 87/87 [==============================] - 1129s 13s/step - loss: 0.0134 - accuracy: 0.9975 - precision: 0.9976 - recall: 0.9975 - val_loss: 0.1897 - val_accuracy: 0.9681 - val_precision: 0.9681 - val_recall: 0.9681 - lr: 5.0000e-06
# Epoch 10/10
# 87/87 [==============================] - 1133s 13s/step - loss: 0.0153 - accuracy: 0.9973 - precision: 0.9973 - recall: 0.9973 - val_loss: 0.1800 - val_accuracy: 0.9697 - val_precision: 0.9697 - val_recall: 0.9697 - lr: 2.5000e-06

# %%
history = model.fit(
    x = train_gen,
    epochs = epochs,
    #class_weight = class_weights,
    batch_size = bs, 
    validation_data = valid_gen,
    callbacks = aug_callbacks
).history
# Out:
# Epoch 1/10
# 87/87 [==============================] - 8234s 95s/step - loss: 0.0113 - accuracy: 0.9980 - precision: 0.9980 - recall: 0.9980 - val_loss: 0.1920 - val_accuracy: 0.9657 - val_precision: 0.9657 - val_recall: 0.9657 - lr: 2.5000e-06
# Epoch 2/10
# 87/87 [==============================] - 162s 2s/step - loss: 0.0112 - accuracy: 0.9982 - precision: 0.9982 - recall: 0.9982 - val_loss: 0.1927 - val_accuracy: 0.9657 - val_precision: 0.9657 - val_recall: 0.9657 - lr: 2.5000e-06
# Epoch 3/10
# 87/87 [==============================] - 161s 2s/step - loss: 0.0146 - accuracy: 0.9969 - precision: 0.9969 - recall: 0.9969 - val_loss: 0.1874 - val_accuracy: 0.9673 - val_precision: 0.9673 - val_recall: 0.9673 - lr: 2.5000e-06
# Epoch 4/10
# 87/87 [==============================] - 160s 2s/step - loss: 0.0122 - accuracy: 0.9977 - precision: 0.9977 - recall: 0.9975 - val_loss: 0.1897 - val_accuracy: 0.9681 - val_precision: 0.9681 - val_recall: 0.9681 - lr: 2.5000e-06
# Epoch 5/10
# 87/87 [==============================] - 161s 2s/step - loss: 0.0115 - accuracy: 0.9982 - precision: 0.9983 - recall: 0.9981 - val_loss: 0.1877 - val_accuracy: 0.9673 - val_precision: 0.9673 - val_recall: 0.9673 - lr: 2.5000e-06
# Epoch 6/10
# 87/87 [==============================] - 161s 2s/step - loss: 0.0139 - accuracy: 0.9972 - precision: 0.9972 - recall: 0.9971 - val_loss: 0.1981 - val_accuracy: 0.9673 - val_precision: 0.9673 - val_recall: 0.9673 - lr: 2.5000e-06
# Epoch 7/10
# 87/87 [==============================] - 159s 2s/step - loss: 0.0135 - accuracy: 0.9966 - precision: 0.9968 - recall: 0.9965 - val_loss: 0.1890 - val_accuracy: 0.9673 - val_precision: 0.9673 - val_recall: 0.9673 - lr: 2.5000e-06
# Epoch 8/10
# 73/87 [========================>.....] - ETA: 25s - loss: 0.0123 - accuracy: 0.9970 - precision: 0.9971 - recall: 0.9970

# %%
model.save("/content/gdrive/MyDrive/Assignment/MODELS/FCDNP_EffNet_Final") #save the model
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 81). These functions will not be directly callable after loading.

# %% [markdown]
# ##Model evaluation 2

# %%
ret2 = evaluate_model_m(model, test_gen, test_target_cat)
# Out:
# 25/25 [==============================] - 285s 11s/step
# Accuracy: 0.9566763659877142
# F1 score: 0.9408341811574753

# %%
import pickle
with open('/content/gdrive/MyDrive/Assignment/MODELS/FCDNP_EffNet_Final_predictions', 'wb') as f:
    pickle.dump(ret2, f)

# %%
e = ret2['predictions']
e
np.save("/content/gdrive/MyDrive/Assignment/MODELS/FCDNP_EffNet_Final_predictions",e)
